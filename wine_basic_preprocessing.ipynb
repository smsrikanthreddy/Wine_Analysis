# %%
import numpy as np
import pandas as pd

# %%
DATAPATH = 'data/wine_dataset.csv'
data = pd.read_csv(DATAPATH)
data.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality style
# 0      9.4        5   red
# 1      9.8        5   red
# 2      9.8        5   red
# 3      9.8        6   red
# 4      9.4        5   red

# %%
data.shape
# Out:
# (6497, 13)

# %%
#as each feature has diff ranges, lets normalize it
def normalize(x):
    min_x = min(x)
    max_x = max(x)
    return (x - min_x)/(max_x - min_x)

# %%
data.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'style'],
#       dtype='object')

# %%
cols = ['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
       'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
       'pH', 'sulphates', 'alcohol']
for col in cols:
    new_col_name = 'norm_'+col
    data[new_col_name] = normalize(data[col])

# %%
data.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#        ...       norm_volatile_acidity  norm_citric_acid norm_residual_sugar  \
# 0      ...                    0.413333          0.000000            0.019939
# 1      ...                    0.533333          0.000000            0.030675
# 2      ...                    0.453333          0.024096            0.026074
# 3      ...                    0.133333          0.337349            0.019939
# 4      ...                    0.413333          0.000000            0.019939
#
#    norm_chlorides  norm_free_sulfur_dioxide  norm_total_sulfur_dioxide  \
# 0        0.111296                  0.034722                   0.064516
# 1        0.147841                  0.083333                   0.140553
# 2        0.137874                  0.048611                   0.110599
# 3        0.109635                  0.055556                   0.124424
# 4        0.111296                  0.034722                   0.064516
#
#    norm_density   norm_pH  norm_sulphates  norm_alcohol
# 0      0.206092  0.612403        0.191011      0.202899
# 1      0.186813  0.372093        0.258427      0.260870
# 2      0.190669  0.418605        0.241573      0.260870
# 3      0.209948  0.341085        0.202247      0.260870
# 4      0.206092  0.612403        0.191011      0.202899
#
# [5 rows x 24 columns]

# %% [markdown]
# We need to predict the quality of the wine produced which will improve the sales.
# So we are converting the style and quality columns into one-hot encoding and categories

# %%
#style column one-hot encoding
style_R_W = pd.get_dummies(data['style'])
style_R_W.head()
# Out:
#    red  white
# 0    1      0
# 1    1      0
# 2    1      0
# 3    1      0
# 4    1      0

# %%
data = pd.concat([data, style_R_W], axis=1)
data.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  ...    \
# 0                 11.0                  34.0   0.9978  3.51       0.56  ...
# 1                 25.0                  67.0   0.9968  3.20       0.68  ...
# 2                 15.0                  54.0   0.9970  3.26       0.65  ...
# 3                 17.0                  60.0   0.9980  3.16       0.58  ...
# 4                 11.0                  34.0   0.9978  3.51       0.56  ...
#
#    norm_residual_sugar  norm_chlorides norm_free_sulfur_dioxide  \
# 0             0.019939        0.111296                 0.034722
# 1             0.030675        0.147841                 0.083333
# 2             0.026074        0.137874                 0.048611
# 3             0.019939        0.109635                 0.055556
# 4             0.019939        0.111296                 0.034722
#
#    norm_total_sulfur_dioxide  norm_density   norm_pH  norm_sulphates  \
# 0                   0.064516      0.206092  0.612403        0.191011
# 1                   0.140553      0.186813  0.372093        0.258427
# 2                   0.110599      0.190669  0.418605        0.241573
# 3                   0.124424      0.209948  0.341085        0.202247
# 4                   0.064516      0.206092  0.612403        0.191011
#
#    norm_alcohol  red  white
# 0      0.202899    1      0
# 1      0.260870    1      0
# 2      0.260870    1      0
# 3      0.260870    1      0
# 4      0.202899    1      0
#
# [5 rows x 26 columns]

# %% [markdown]
# since we are dealing with quality of wine rather very much focused on ratings from 1 to 10 and due to less
# data available. I would categorize the quality into 3 categories i.e. 'good','ok','bad'

# %%
#lets categorize the quality column
#bad = 0, ok = 1, good = 2
def categorize_quality(x):
    for i, val in enumerate(x.values):
        if val <= 5:
            data.loc[i, 'quality'] = 'bad'
        elif val >= 6 and val <= 7:
            data.loc[i, 'quality'] = 'ok'
        elif val >= 8:
            data.loc[i, 'quality'] = 'good'
        else:
            print('wrong value {}', i)
            
categorize_quality(data['quality'])

# %%
data['quality'] = pd.factorize(data['quality'])[0]

# %%
data.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  ...    \
# 0                 11.0                  34.0   0.9978  3.51       0.56  ...
# 1                 25.0                  67.0   0.9968  3.20       0.68  ...
# 2                 15.0                  54.0   0.9970  3.26       0.65  ...
# 3                 17.0                  60.0   0.9980  3.16       0.58  ...
# 4                 11.0                  34.0   0.9978  3.51       0.56  ...
#
#    norm_residual_sugar  norm_chlorides norm_free_sulfur_dioxide  \
# 0             0.019939        0.111296                 0.034722
# 1             0.030675        0.147841                 0.083333
# 2             0.026074        0.137874                 0.048611
# 3             0.019939        0.109635                 0.055556
# 4             0.019939        0.111296                 0.034722
#
#    norm_total_sulfur_dioxide  norm_density   norm_pH  norm_sulphates  \
# 0                   0.064516      0.206092  0.612403        0.191011
# 1                   0.140553      0.186813  0.372093        0.258427
# 2                   0.110599      0.190669  0.418605        0.241573
# 3                   0.124424      0.209948  0.341085        0.202247
# 4                   0.064516      0.206092  0.612403        0.191011
#
#    norm_alcohol  red  white
# 0      0.202899    1      0
# 1      0.260870    1      0
# 2      0.260870    1      0
# 3      0.260870    1      0
# 4      0.202899    1      0
#
# [5 rows x 26 columns]

# %%
#lets drop columns some columns as we have transformed those columns into new values
data.columns
drop_cols = ['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
       'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
       'pH', 'sulphates', 'alcohol','style']

data.drop(drop_cols, axis=1, inplace=True)

# %%
data.head()
# Out:
#    quality  norm_fixed_acidity  norm_volatile_acidity  norm_citric_acid  \
# 0        0            0.297521               0.413333          0.000000
# 1        0            0.330579               0.533333          0.000000
# 2        0            0.330579               0.453333          0.024096
# 3        1            0.611570               0.133333          0.337349
# 4        0            0.297521               0.413333          0.000000
#
#    norm_residual_sugar  norm_chlorides  norm_free_sulfur_dioxide  \
# 0             0.019939        0.111296                  0.034722
# 1             0.030675        0.147841                  0.083333
# 2             0.026074        0.137874                  0.048611
# 3             0.019939        0.109635                  0.055556
# 4             0.019939        0.111296                  0.034722
#
#    norm_total_sulfur_dioxide  norm_density   norm_pH  norm_sulphates  \
# 0                   0.064516      0.206092  0.612403        0.191011
# 1                   0.140553      0.186813  0.372093        0.258427
# 2                   0.110599      0.190669  0.418605        0.241573
# 3                   0.124424      0.209948  0.341085        0.202247
# 4                   0.064516      0.206092  0.612403        0.191011
#
#    norm_alcohol  red  white
# 0      0.202899    1      0
# 1      0.260870    1      0
# 2      0.260870    1      0
# 3      0.260870    1      0
# 4      0.202899    1      0

# %%
data.shape
# Out:
# (6497, 14)

# %%
#lets save the data into a csv
data.to_csv('data/basic_preprocessed.csv')
